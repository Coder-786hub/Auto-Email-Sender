# %%
import pandas as pd

# %%
students_data = [
    {"S.No": 1, "Name": "Sahil", "Mobile": "", "Email": "enough1947@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 2, "Name": "Anmol", "Mobile": "", "Email": "anmolsharma67539@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 3, "Name": "Disha", "Mobile": "", "Email": "dishalangeh0322@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 4, "Name": "Sejal", "Mobile": "", "Email": "sharmaa05807@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 5, "Name": "Ritika", "Mobile": "", "Email": "sharmar8567@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 6, "Name": "Deepak", "Mobile": "", "Email": "dk8159969@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 7, "Name": "Himani", "Mobile": "", "Email": "Bishthimani2005@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 8, "Name": "Sandhaya", "Mobile": "", "Email": "sandhyarajput0104@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 9, "Name": "Ankit", "Mobile": "", "Email": "ankitkumar547888@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 10, "Name": "Tanya", "Mobile": "", "Email": "Kaurtanya2021@gmail.com", "Batch": "10:00 AM"},

    {"S.No": 11, "Name": "Satyam", "Mobile": "", "Email": "satyamdua182182@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 12, "Name": "Anjali", "Mobile": "", "Email": "Anjali08aug@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 13, "Name": "Janvi", "Mobile": "", "Email": "janvijoshi2806@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 14, "Name": "Neema", "Mobile": "", "Email": "lk8910379@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 15, "Name": "Vinayak", "Mobile": "", "Email": "v367nayak@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 16, "Name": "Akshit", "Mobile": "", "Email": "business.akshitsharma@gmail.com", "Batch": "12:00 PM"},

    {"S.No": 17, "Name": "Aaryan", "Mobile": "", "Email": "aryansharma.q123@gmail.com", "Batch": "11:00 AM"},
    {"S.No": 18, "Name": "Rahul", "Mobile": "", "Email": "singhrahul80690@gmail.com", "Batch": "11:00 AM"},
    {"S.No": 19, "Name": "Uday Pratap Singh", "Mobile": "", "Email": "brarudaypartapsingh@gmail.com", "Batch": "11:00 AM"},

    {"S.No": 20, "Name": "Aashish", "Mobile": "", "Email": "gashishkumar2201@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 21, "Name": "Vanita", "Mobile": "", "Email": "Vanitakumari00786@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 22, "Name": "Jaisleen", "Mobile": "", "Email": "jaisleen47@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 23, "Name": "Kamal", "Mobile": "", "Email": "Kamalpreetsamra.1997@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 24, "Name": "Nidhi", "Mobile": "", "Email": "nidhisharma57350@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 25, "Name": "Saisneha", "Mobile": "", "Email": "saisneha0209@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 26, "Name": "Akansha", "Mobile": "", "Email": "akanshauniyal1129@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 27, "Name": "Aftab", "Mobile": "", "Email": "aftabalamkhan8932@gmail.com", "Batch": "5:30 PM"},
    {"S.No": 28, "Name": "Shahbaz", "Mobile": "", "Email": "shahbazahmadkhan14@gmail.com", "Batch": "5:30 PM"},
    
]

# %%
data = pd.DataFrame(students_data)

# %%
data.to_excel("students.xlsx")

# %%
pd.read_csv("students.xlsx", enconding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_csv("students.xlsx", enconde = "utf-8")
#
# TypeError: read_csv() got an unexpected keyword argument 'enconde'
