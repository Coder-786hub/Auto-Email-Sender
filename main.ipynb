# %%
import pandas as pd

# %%
students_data = [
    {"S.No": 1, "Name": "Sahil", "Mobile": "", "Email": "enough1947@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 2, "Name": "Anmol", "Mobile": "", "Email": "anmolsharma67539@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 3, "Name": "Disha", "Mobile": "", "Email": "dishalangeh0322@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 4, "Name": "Sejal", "Mobile": "", "Email": "sharmaa05807@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 5, "Name": "Ritika", "Mobile": "", "Email": "sharmar8567@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 6, "Name": "Deepak", "Mobile": "", "Email": "dk8159969@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 7, "Name": "Himani", "Mobile": "", "Email": "Bishthimani2005@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 8, "Name": "Sandhaya", "Mobile": "", "Email": "sandhyarajput0104@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 9, "Name": "Ankit", "Mobile": "", "Email": "ankitkumar547888@gmail.com", "Batch": "10:00 AM"},
    {"S.No": 10, "Name": "Tanya", "Mobile": "", "Email": "Kaurtanya2021@gmail.com", "Batch": "10:00 AM"},

    {"S.No": 11, "Name": "Sahil", "Mobile": "", "Email": "enough1947@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 12, "Name": "Anmol", "Mobile": "", "Email": "anmolsharma67539@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 13, "Name": "Sandhaya", "Mobile": "", "Email": "sandhyarajput0104@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 14, "Name": "Satyam", "Mobile": "", "Email": "satyamdua182182@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 15, "Name": "Janvi", "Mobile": "", "Email": "janvijoshi2806@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 16, "Name": "Neema", "Mobile": "", "Email": "lk8910379@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 17, "Name": "Vinayak", "Mobile": "", "Email": "v367nayak@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 18, "Name": "Akshit", "Mobile": "", "Email": "business.akshitsharma@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 19, "Name": "Aaryan", "Mobile": "", "Email": "aryansharma.q123@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 20, "Name": "Rahul", "Mobile": "", "Email": "singhrahul80690@gmail.com", "Batch": "12:00 PM"},
    {"S.No": 21, "Name": "Uday Pratap Singh", "Mobile": "", "Email": "brarudaypartapsingh@gmail.com", "Batch": "12:00 PM"},

    {"S.No": 22, "Name": "Aashish", "Mobile": "", "Email": "gashishkumar2201@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 23, "Name": "Vanita", "Mobile": "", "Email": "Vanitakumari00786@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 24, "Name": "Jaisleen", "Mobile": "", "Email": "jaisleen47@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 25, "Name": "Kamal", "Mobile": "", "Email": "Kamalpreetsamra.1997@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 26, "Name": "Nidhi", "Mobile": "", "Email": "nidhisharma57350@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 27, "Name": "Saisneha", "Mobile": "", "Email": "saisneha0209@gmail.com", "Batch": "4:30 PM"},
    {"S.No": 28, "Name": "Akansha", "Mobile": "", "Email": "akanshauniyal1129@gmail.com", "Batch": "4:30 PM"},
]

# %%
data = pd.DataFrame(students_data)
data
# Out:
#     S.No               Name Mobile                            Email     Batch
# 0      1              Sahil                    enough1947@gmail.com  10:00 AM
# 1      2              Anmol              anmolsharma67539@gmail.com  10:00 AM
# 2      3              Disha               dishalangeh0322@gmail.com  10:00 AM
# 3      4              Sejal                  sharmaa05807@gmail.com  10:00 AM
# 4      5             Ritika                   sharmar8567@gmail.com  10:00 AM
# 5      6             Deepak                     dk8159969@gmail.com  10:00 AM
# 6      7             Himani               Bishthimani2005@gmail.com  10:00 AM
# 7      8           Sandhaya             sandhyarajput0104@gmail.com  10:00 AM
# 8      9              Ankit              ankitkumar547888@gmail.com  10:00 AM
# 9     10              Tanya                 Kaurtanya2021@gmail.com  10:00 AM
# 10    11              Sahil                    enough1947@gmail.com  12:00 PM
# ...

# %%
data.to_excel("students.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data.to_excel("students.xlsx")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...

# %%
# df = pd.read_csv("students.xlsx")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv("students.xlsx")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
data = pd.read_excel("students.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0  S.No    Name  Mobile                       Email     Batch
# 0           0     1   Sahil     NaN        enough1947@gmail.com  10:00 AM
# 1           1     2   Anmol     NaN  anmolsharma67539@gmail.com  10:00 AM
# 2           2     3   Disha     NaN   dishalangeh0322@gmail.com  10:00 AM
# 3           3     4   Sejal     NaN      sharmaa05807@gmail.com  10:00 AM
# 4           4     5  Ritika     NaN       sharmar8567@gmail.com  10:00 AM

# %%
data.to_excel("student_data.xlsx")

# %%
data
# Out:
#     Unnamed: 0  S.No               Name  Mobile  \
# 0            0     1              Sahil     NaN
# 1            1     2              Anmol     NaN
# 2            2     3              Disha     NaN
# 3            3     4              Sejal     NaN
# 4            4     5             Ritika     NaN
# 5            5     6             Deepak     NaN
# 6            6     7             Himani     NaN
# 7            7     8           Sandhaya     NaN
# 8            8     9              Ankit     NaN
# 9            9    10              Tanya     NaN
# 10          10    11              Sahil     NaN
# 11          11    12              Anmol     NaN
# 12          12    13           Sandhaya     NaN
# 13          13    14             Satyam     NaN
# 14          14    15              Janvi     NaN
# 15          15    16              Neema     NaN
# 16          16    17            Vinayak     NaN
# 17          17    18             Akshit     NaN
# ...
